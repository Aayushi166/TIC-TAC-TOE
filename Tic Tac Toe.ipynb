# %%
Board = {'1':' ','2':' ','3':' ','4':' ','5':' ','6':' ','7':' ','8':' ','9':' '}

# %%
def print_board(Board):
    print(Board['1']+'|'+ Board['2']+'|'+ Board['3'])
    print("_ _ _")
    print(Board['4']+'|'+ Board['5']+'|'+ Board['6']) 
    print("_ _ _")
    print(Board['7']+'|'+ Board['8']+'|'+ Board['9'])

# %%
def board_pos(Board):
    print(Board['1']+'|'+ Board['2']+'|'+ Board['3'])
    print("_1_2_3")
    print(Board['4']+'|'+ Board['5']+'|'+ Board['6']) 
    print("_4_5_6")
    print(Board['7']+'|'+ Board['8']+'|'+ Board['9'])
    print(" 7 8 9")

# %%
def game():
    count = 0
    print("Welcome to TIC TAC TOE.  Let's begin!!")
    print('The Board Position:- ')
    board_pos(Board)
    print('Turn on your Caps Lock Key')
    print('Choose your sign players')
    P1=input('X OR O :- ')
    if P1=='X':
        P2 = 'O'
        print('Player 1 = X and Player 2 = O' )
        
    elif P1 == 'O':
        P2 = 'X'
        print('Player 1 = O and Player 2 = X' )
        
    turn = P1
    
    for i in range(10):
        print_board(Board)
        print("It's your turn "+turn+' Which position to mark')
        move = input()
        
        if Board[move]==' ':
            Board[move]= turn
            count+=1
            
        else:
            print('Position already marked')
            continue
            
        if count>=5:    
            if Board['1']==Board['2']==Board['3']!= ' ':
                print(turn,'Won :)')
                print_board(Board)
                break
                
            elif Board['4']==Board['5']==Board['6']!= ' ':
                print(turn,'Won :)')
                print_board(Board)
                break
                
            elif Board['7']==Board['8']==Board['9']!= ' ':
                print(turn,'Won :)')
                print_board(Board)
                break
                
            elif Board['1']==Board['5']==Board['9']!= ' ':
                print(turn,'Won :)')
                print_board(Board)
                break
                
            elif Board['3']==Board['5']==Board['7']!= ' ':
                print(turn,'Won :)')
                print_board(Board)
                break
            elif Board['1']==Board['4']==Board['7']!= ' ':
                print(turn,'Won :)')
                print_board(Board)
                break 
            elif Board['2']==Board['5']==Board['8']!= ' ':
                print(turn,'Won :)')
                print_board(Board)
                break
            elif Board['3']==Board['6']==Board['9']!= ' ':
                print(turn,'Won :)')
                print_board(Board)
                break    
            
        if count==9:
            print('Its a tie')
            print_board(Board)
            break
            
        if turn == P1:
            turn = P2
        else:
            turn = P1
